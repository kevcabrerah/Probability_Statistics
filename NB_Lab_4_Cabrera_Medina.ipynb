# %% [markdown]
# <a href="https://colab.research.google.com/github/kevcabrerah/Probability_Statistics/blob/main/NB_Lab_4_Cabrera_Medina.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from skimage.io import imread

# %%
url = 'https://static.toiimg.com/thumb/msid-64610266,width-1070,height-580,imgsize-72814,resizemode-75,overlay-toi_sw,pt-32,y_pad-40/photo.jpg'

# %%
im = imread(url)

# %%
plt.figure(figsize=(20,10))
plt.imshow(im);
plt.axis('off');

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([11,25,34,47])

# %% [markdown]
# A numpy array is a grid of values, all of the same type, and is indexed by a tuple of nonnegative integers

# %%
# population

# %%
np.sum(x)
# Out:
# 117

# %% [markdown]
# Added up the numbers together in np.array

# %%
x.shape[0]
# Out:
# 4

# %% [markdown]
#  give the number of rows in an array

# %%
np.sum(x)/x.shape[0]
# Out:
# 29.25

# %% [markdown]
# you take the sum of the np.array and the rows and devided to receive your answer

# %%
def mean(x):
    return np.sum(x)/x.shape[0]

# %% [markdown]
# def key word it to descride a defining function

# %%
mean(x)
# Out:
# 29.25

# %% [markdown]
# this is the mean of the 4 numbers

# %%
x
# Out:
# array([11, 25, 34, 47])

# %% [markdown]
# x values

# %%
x - mean(x)
# Out:
# array([-18.25,  -4.25,   4.75,  17.75])

# %% [markdown]
# you get your x values and sumbtracted by the mean

# %%
x - mean(x)**2
# Out:
# array([-844.5625, -830.5625, -821.5625, -808.5625])
