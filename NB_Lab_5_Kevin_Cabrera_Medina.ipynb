# %% [markdown]
# <a href="https://colab.research.google.com/github/kevcabrerah/Probability_Statistics/blob/main/NB_Lab_5_Kevin_Cabrera_Medina.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
def get_database(url):
    url_head = "https://docs.google.com/spreadsheets/d/"
    url_foot = "/gviz/tq?tqx=out:csv&sheet="
    url_body = url.split('/')[5]
    sheet_name = "1"
    url_csv = url_head + url_body + url_foot + sheet_name
    df = pd.read_csv(url_csv, sep=',', skiprows=0)
    return df

# %% [markdown]
# import pandas as pd is tells Python to give pandas the alias of pd
#
# import matplotlib.pyplot as plt is pyplot is a module, rather than a function which could be incorrectly assumed from the first form

# %%
url = 'https://docs.google.com/spreadsheets/d/1B_HW2uVGQv9W7b6vVZDSkOPLtmfodHrX4G0qtQbIenk/edit#gid=0'

# %% [markdown]
# this put the url data info on to colab

# %%
data = get_database(url)

# %% [markdown]
#  specify the subprotocol (the database connectivity mechanism), the database or server identifier, and a list of properties

# %%
data
# Out:
#    Distance (megaparsecs)  Buonocore  Nicolas Ovando  Chris Cravens  Sepanek  \
# 0                NGC 1357       22.4            75.6           22.3     53.3
# 1                NGC 1832       27.7            32.8           28.4     39.3
# 2                NGC 2276       29.3            33.2           29.9     34.2
# 3                NGC 2775       46.0            31.9           27.5     33.1
# 4                NGC 2903       46.6            15.1            6.5     26.4
# 5                NGC 3034       17.7            34.9            6.9     10.3
# 6                NGC 3147       30.2            40.1           21.3     36.4
# 7                NGC 3227       43.7            25.3           17.9     30.8
# 8                NGC 3368       87.6            25.4            9.7     26.2
# 9                NGC 3623       30.7            14.0            8.0     11.2
# 10               NGC 3627       33.4            14.7            8.8     13.0
# ...

# %% [markdown]
# this is the data table that was on the spreadsheet

# %%
data = np.array(data)

# %%
data
# Out:
# array([['NGC 1357', 22.4, 75.6, 22.3, 53.3, 46.4, 22.4, 22.5, 22.4, 25.2,
#         9.8, 22.7, 19.8, 38.5, 23.4, 22.4, 21.9, 22.8, 23.6, 48.9, 23.1,
#         41.5, 36.2, 21.1, 22.4, 21.4, 28.5, 24.1, 22.4, 44.0, 22.4, 41.6,
#         60.6, 38.1, 28.1, 22.4, 22.0, 22.4, 40.6, 22.4, 22.4, 22.7, 22.4,
#         22.4, 22.5, 22.4, 22.4, 22.4, 27.0, 22.4, 71.2, 22.4],
#        ['NGC 1832', 27.7, 32.8, 28.4, 39.3, 34.5, 27.8, 29.7, 27.7, 30.2,
#         29.4, 34.3, 22.3, 29.8, 28.5, 27.7, 24.7, 30.5, 25.2, 32.7, 24.1,
#         48.2, 30.3, 26.5, 26.6, 25.2, 23.9, 24.6, 40.8, 40.7, 27.7, 37.7,
#         145.3, 28.1, 27.7, 57.1, 27.8, 27.7, 35.7, 27.7, 27.7, 28.1,
#         27.7, 27.7, 27.2, 27.7, 37.5, 27.7, 28.3, 27.7, 40.3, 27.7],
#        ['NGC 2276', 29.3, 33.2, 29.9, 34.2, 30.8, 29.3, 32.9, 25.9, 31.0,
#         26.1, 31.5, 30.3, 29.2, 28.8, 29.3, 26.1, 27.2, 31.1, 31.1, 29.2,
#         34.3, 27.6, 30.1, 29.8, 28.4, 27.0, 27.1, 40.6, 34.3, 29.3, 31.7,
# ...

# %%
data.shape
# Out:
# (18, 52)

# %%
colors = data[:,1]

# %%
colors
# Out:
# array([22.4, 27.7, 29.3, 46.0, 46.6, 17.7, 30.2, 43.7, 87.6, 30.7, 33.4,
#        188.8, 22.7, 10.2, 34.0, 7.6, 8.2, 11.3], dtype=object)

# %%
colors == 'Red'
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False])

# %%
red_count = np.sum(colors == 'Red')

# %%
blue_count = np.sum(colors == 'Red')

# %%
names = ['Red', 'Blue']
values = [red_count, blue_count]

plt.bar(names, values, color=['red', 'blue'])
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# there should be color in here but it dshoud show to columns. One is red and the other is blue.
#
# name = is how you name the to columns
